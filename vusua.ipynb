# %%
#import library
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=20,
                                                 directory='../input/traindulieu/train',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=20,
                                                 directory='../input/testdulieu/test',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 1152 images belonging to 12 classes.
# Found 72 images belonging to 12 classes.

# %%
train_dataset.classes
train_dataset.class_indices
# Out:
# {'L1': 0,
#  'L10': 1,
#  'L11': 2,
#  'L12': 3,
#  'L2': 4,
#  'L3': 5,
#  'L4': 6,
#  'L5': 7,
#  'L6': 8,
#  'L7': 9,
#  'L8': 10,
#  'L9': 11}

# %%
import numpy as np  
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks 
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-06-22 19:10:42.507062: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dense, Activation, Flatten
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(12,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                1548
# =================================================================
# Total params: 5,597,100
# Trainable params: 5,597,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=40,epochs=100,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-06-22 19:10:43.148514: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 58/58 [==============================] - 63s 1s/step - loss: 2.3820 - accuracy: 0.1589 - val_loss: 1.8385 - val_accuracy: 0.3056
# Epoch 2/100
# 58/58 [==============================] - 69s 1s/step - loss: 1.6551 - accuracy: 0.3429 - val_loss: 1.4078 - val_accuracy: 0.3333
# Epoch 3/100
# 58/58 [==============================] - 71s 1s/step - loss: 1.4167 - accuracy: 0.4184 - val_loss: 1.6953 - val_accuracy: 0.3056
# Epoch 4/100
# 58/58 [==============================] - 64s 1s/step - loss: 1.2036 - accuracy: 0.4861 - val_loss: 1.1479 - val_accuracy: 0.4444
# Epoch 5/100
# 58/58 [==============================] - 64s 1s/step - loss: 1.0612 - accuracy: 0.5347 - val_loss: 1.1985 - val_accuracy: 0.5000
# Epoch 6/100
# 58/58 [==============================] - 64s 1s/step - loss: 0.9396 - accuracy: 0.6016 - val_loss: 1.0518 - val_accuracy: 0.5000
# Epoch 7/100
# 58/58 [==============================] - 65s 1s/step - loss: 0.8443 - accuracy: 0.6389 - val_loss: 1.1504 - val_accuracy: 0.4167
# Epoch 8/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.7995 - accuracy: 0.6693 - val_loss: 1.2674 - val_accuracy: 0.4444
# Epoch 9/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.6854 - accuracy: 0.6997 - val_loss: 1.2825 - val_accuracy: 0.5278
# Epoch 10/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.6259 - accuracy: 0.7370 - val_loss: 1.4673 - val_accuracy: 0.4722
# Epoch 11/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.7702 - accuracy: 0.6840 - val_loss: 1.0596 - val_accuracy: 0.4722
# Epoch 12/100
# 58/58 [==============================] - 61s 1s/step - loss: 0
100
# 58/58 [==============================] - 64s 1s/step - loss: 0.0453 - accuracy: 0.9861 - val_loss: 1.3766 - val_accuracy: 0.7500
# Epoch 40/100
# 58/58 [==============================] - 64s 1s/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 1.7246 - val_accuracy: 0.6111
# Epoch 41/100
# 58/58 [==============================] - 66s 1s/step - loss: 0.0461 - accuracy: 0.9835 - val_loss: 1.2549 - val_accuracy: 0.7222
# Epoch 42/100
# 58/58 [==============================] - 65s 1s/step - loss: 0.0435 - accuracy: 0.9861 - val_loss: 2.1540 - val_accuracy: 0.5833
# Epoch 43/100
# 58/58 [==============================] - 63s 1s/step - loss: 0.0877 - accuracy: 0.9722 - val_loss: 1.5339 - val_accuracy: 0.6667
# Epoch 44/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0920 - accuracy: 0.9679 - val_loss: 1.4686 - val_accuracy: 0.5833
# Epoch 45/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0489 - accuracy: 0.9861 - val_loss: 1.2623 - val_accuracy: 0.6944
# Epoch 46/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 1.2660 - val_accuracy: 0.7500
# Epoch 47/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0282 - accuracy: 0.9939 - val_loss: 1.3095 - val_accuracy: 0.8056
# Epoch 48/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0206 - accuracy: 0.9948 - val_loss: 1.8956 - val_accuracy: 0.6667
# Epoch 49/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0268 - accuracy: 0.9922 - val_loss: 1.2190 - val_accuracy: 0.7778
# Epoch 50/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0097 - accuracy: 0.9991 - val_loss: 1.4072 - val_accuracy: 0.7500
# Epoch 51/100
# 58/58 [==============================] - 63s 1s/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 1.4827 - val_accuracy: 0.7778
# Epoch 52/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 1.2053 - val_accuracy: 0.7778
# Epoch 53/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0324 - accuracy: 0.9878 - val_loss: 1.1753 - val_accuracy: 0.7778
# Epoch 54/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 1.4884 - val_accuracy: 0.6667
# Epoch 55/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 1.5953 - val_accuracy: 0.7500
# Epoch 56/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0114 - accuracy: 0.9983 - val_loss: 1.7139 - val_accuracy: 0.7222
# Epoch 57/100
# 58/58 [==============================] - 64s 1s/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 1.9692 - val_accuracy: 0.6389
# Epoch 58/100
# 58/58 [==============================] - 64s 1s/step - loss: 0.0308 - accuracy: 0.9887 - val_loss: 1.8214 - val_accuracy: 0.6667
# Epoch 59/100
# 58/58 [==============================] - 65s 1s/step - loss: 0.0205 - accuracy: 0.9887 - val_loss: 2.0412 - val_accuracy: 0.6667
# Epoch 60/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0329 - accuracy: 0.9870 - val_loss: 2.0731 - val_accuracy: 0.6389
# Epoch 61/100
# 58/58 [==============================] - 62s 1s/step - loss: 0.0389 - accuracy: 0.9887 - val_loss: 1.6743 - val_accuracy: 0.6667
# Epoch 62/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0261 - accuracy: 0.9878 - val_loss: 1.5638 - val_accuracy: 0.6667
# Epoch 63/100
# 58/58 [==============================] - 62s 1s/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 1.6519 - val_accuracy: 0.6944
# Epoch 64/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 1.6611 - val_accuracy: 0.6667
# Epoch 65/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 2.1533 - val_accuracy: 0.6389
# Epoch 66/100
# 58/58 [==============================] - 62s 1s/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 1.9006 - val_accuracy: 0.7222
# Epoch 67/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0254 - accuracy: 0.9896 - val_loss: 2.6145 - val_accuracy: 0.6389
# Epoch 68/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0856 - accuracy: 0.9835 - val_loss: 2.0199 - val_accuracy: 0.6389
# Epoch 69/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0095 - accuracy: 0.9991 - val_loss: 2.1727 - val_accuracy: 0.6667
# Epoch 70/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 2.2288 - val_accuracy: 0.6944
# Epoch 71/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0122 - accuracy: 0.9939 - val_loss: 1.6983 - val_accuracy: 0.7778
# Epoch 72/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0151 - accuracy: 0.9939 - val_loss: 1.7624 - val_accuracy: 0.6944
# Epoch 73/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 1.6792 - val_accuracy: 0.6944
# Epoch 74/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 1.7538 - val_accuracy: 0.5833
# Epoch 75/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 1.9504 - val_accuracy: 0.7222
# Epoch 76/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 1.7635 - val_accuracy: 0.6667
# Epoch 77/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0198 - accuracy: 0.9939 - val_loss: 1.4215 - val_accuracy: 0.7222
# Epoch 78/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0587 - accuracy: 0.9835 - val_loss: 1.7115 - val_accuracy: 0.6389
# Epoch 79/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 1.7880 - val_accuracy: 0.6389
# Epoch 80/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 1.7762 - val_accuracy: 0.6667
# Epoch 81/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.6402 - val_accuracy: 0.6944
# Epoch 82/100
# 58/58 [==============================] - 62s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.8156 - val_accuracy: 0.6667
# Epoch 83/100
# 58/58 [==============================] - 62s 1s/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 1.7604 - val_accuracy: 0.6667
# Epoch 84/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0368 - accuracy: 0.9905 - val_loss: 1.5779 - val_accuracy: 0.6389
# Epoch 85/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0293 - accuracy: 0.9939 - val_loss: 1.8650 - val_accuracy: 0.6667
# Epoch 86/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 1.6512 - val_accuracy: 0.7778
# Epoch 87/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0296 - accuracy: 0.9896 - val_loss: 1.7216 - val_accuracy: 0.6389
# Epoch 88/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0394 - accuracy: 0.9861 - val_loss: 1.6456 - val_accuracy: 0.7778
# Epoch 89/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 1.7586 - val_accuracy: 0.6944
# Epoch 90/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 1.9375 - val_accuracy: 0.6111
# Epoch 91/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.2272 - val_accuracy: 0.6389
# Epoch 92/100
# 58/58 [==============================] - 58s 993ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 2.1195 - val_accuracy: 0.5556
# Epoch 93/100
# 58/58 [==============================] - 58s 1s/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 1.7971 - val_accuracy: 0.6667
# Epoch 94/100
# 58/58 [==============================] - 58s 992ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 1.8621 - val_accuracy: 0.6389
# Epoch 95/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 1.9386 - val_accuracy: 0.6389
# Epoch 96/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 1.8526 - val_accuracy: 0.6944
# Epoch 97/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0582 - val_accuracy: 0.6389
# Epoch 98/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 1.9512 - val_accuracy: 0.6667
# Epoch 99/100
# 58/58 [==============================] - 61s 1s/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 2.0656 - val_accuracy: 0.6667
# Epoch 100/100
# 58/58 [==============================] - 60s 1s/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 2.0188 - val_accuracy: 0.7500

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','validation'])
plt.show()

# %%
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  2.0187671184539795
# Độ chính xác  0.75

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L1/L1 (1).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng tròn , loại bình thường
# 99.95662569999695 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L1/L1 (10).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng tròn , loại bình thường
# 99.13942217826843 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L1/L1 (12).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng tròn , loại bình thường
# 99.94140863418579 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L10/L10 (2).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật
# 61.23618483543396 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L11/L11 (16).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường
# 96.27360701560974 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L11/L11 (30).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật
# 99.95465874671936 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L11/L11 (5).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật
# 99.9998927116394 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L12/L12 (10).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường
# 99.99980926513672 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L12/L12 (19).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật
# 97.12817668914795 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L12/L12 (29).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật
# 99.99977350234985 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L12/L12 (44).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật
# 99.99926090240479 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L2/L2 (2).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa hồng , hình dạng tròn, loại bình thường
# 98.85141253471375 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L2/L2 (53).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa hồng , hình dạng tròn, loại bình thường
# 100.0 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L3/L3 (13).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại bình thường
# 95.48210501670837 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L3/L3 (1).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại khuyết tật
# 99.67672824859619 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L4/L4 (10).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường
# 99.98737573623657 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L4/L4 (16).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu vàng , hình dạng tròn , loại bình thường
# 87.48038411140442 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L5/L5 (14).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường
# 98.91536831855774 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L5/L5 (21).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường
# 99.98340606689453 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L5/L5 (28).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường
# 99.99641180038452 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L6/L6 (17).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường
# 98.5674798488617 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L6/L6 (18).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường
# 79.57534193992615 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L8/L8 (22).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu hồng , hình dạng tròn , loại khuyết tật
# 100.0 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L8/L8 (21).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu hồng , hình dạng tròn , loại khuyết tật
# 100.0 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L9/L9 (15).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại khuyết tật
# 96.05295658111572 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L9/L9 (30).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại khuyết tật
# 100.0 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L9/L9 (42).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại khuyết tật
# 99.99172687530518 % dự đoán chính xác

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testdulieu/test/L9/L9 (17).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Vú sữa màu xanh , hình dạng tròn , loại bình thường")
if(kq==1):
    print("Vú sữa màu vàng, hình dạng tròn, loại khuyết tật")
if(kq==2):
        print("Vú sữa xanh , hình dạng không tròn đều , loại khuyết tật")
if(kq==3):
     print("Vú sữa vàng, hình dạng không tròn đều, loại khuyết tật")
if(kq==4):
    print("Vú sữa hồng , hình dạng tròn, loại bình thường")
if(kq==5):
    print("Vú sữa màu tím, hình dạng tròn, loại bình thường")
if(kq==6):
     print("Vú sữa màu vàng , hình dạng tròn , loại bình thường")
if(kq==7):
     print("Vú sữa màu xanh , hình dạng không tròn đều, loại bình thường ")
if(kq==8):
    print("Vú sữa màu vàng, hình dạng không tròn đều , loại bình thường ")
if(kq==9):
     print("Vú sữa màu xành , hình dạng tròn, loại khuyết tật ")
if(kq==10):
       print("Vú sữa màu hồng , hình dạng tròn , loại khuyết tật ")
if(kq==11):
       print("Vú sữa màu tím, hình dạng tròn, loại khuyết tật") 
y_pred = model.predict(img)
x=y_pred.max()
x=x*100
print(x,"% dự đoán chính xác")
# Out:
# Vú sữa màu tím, hình dạng tròn, loại khuyết tật
# 99.36227202415466 % dự đoán chính xác
