# %%
#import library
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/faceanh/train',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/testanh/test',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 84 images belonging to 3 classes.
# Found 3 images belonging to 3 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'loi': 0, 'manh': 1, 'tai': 2}

# %%
import numpy as np  
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM # chuan cua ANN
from keras.models import Sequential #
from tensorflow.keras.utils import to_categorical #  de dam bao do chinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-24 07:26:14.895438: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dense, Activation, Flatten
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=32,epochs=50,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-24 07:26:16.178778: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 9/9 [==============================] - 11s 1s/step - loss: 2.0919 - accuracy: 0.4762 - val_loss: 1.0431 - val_accuracy: 0.3333
# Epoch 2/50
# 9/9 [==============================] - 9s 937ms/step - loss: 0.6913 - accuracy: 0.7143 - val_loss: 0.8089 - val_accuracy: 0.6667
# Epoch 3/50
# 9/9 [==============================] - 9s 938ms/step - loss: 0.3774 - accuracy: 0.8690 - val_loss: 0.6935 - val_accuracy: 0.3333
# Epoch 4/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.3208 - accuracy: 0.8929 - val_loss: 1.3491 - val_accuracy: 0.6667
# Epoch 5/50
# 9/9 [==============================] - 9s 957ms/step - loss: 0.1820 - accuracy: 0.9405 - val_loss: 0.1319 - val_accuracy: 1.0000
# Epoch 6/50
# 9/9 [==============================] - 9s 928ms/step - loss: 0.1194 - accuracy: 0.9762 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 7/50
# 9/9 [==============================] - 9s 956ms/step - loss: 0.0878 - accuracy: 0.9643 - val_loss: 0.4918 - val_accuracy: 0.6667
# Epoch 8/50
# 9/9 [==============================] - 9s 920ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.6667
# Epoch 9/50
# 9/9 [==============================] - 9s 960ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.6929 - val_accuracy: 0.6667
# Epoch 10/50
# 9/9 [==============================] - 9s 935ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.1555 - val_accuracy: 0.6667
# Epoch 11/50
# 9/9 [==============================] - 9s 976ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.0109 - val_accuracy: 0.6667
# Epoch 12/50
# 9/9 [==============================] - 9s 928ms/step - loss: 9.0490e-04 - accuracy: 1.0000 - val_loss: 0.9122 - val_accuracy: 0.6667
# Epoch 13/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7017 - val_accuracy: 0.6667
# Epoch 14/50
# 9/9 [==============================] - 9s 960ms/step - loss: 8.9997e-04 - accuracy: 1.0000 - val_loss: 0.5845 - val_accuracy: 0.6667
# Epoch 15/50
# 9/9 [==============================] - 9s 939ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.6667
# Epoch 16/50
# 9/9 [==============================] - 9s 934ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3626 - val_accuracy: 0.6667
# Epoch 17/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3640 - val_accuracy: 0.6667
# Epoch 18/50
# 9/9 [==============================] - 9s 929ms/step - loss: 9.4703e-04 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.6667
# Epoch 19/50
# 9/9 [==============================] - 9s 943ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3938 - val_accuracy: 0.6667
# Epoch 20/50
# 9/9 [==============================] - 9s 968ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3889 - val_accuracy: 0.6667
# Epoch 21/50
# 9/9 [==============================] - 9s 940ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9158 - val_accuracy: 0.6667
# Epoch 22/50
# 9/9 [==============================] - 9s 1s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.7213 - val_accuracy: 0.6667
# Epoch 23/50
# 9/9 [==============================] - 9s 927ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.6667
# Epoch 24/50
# 9/9 [==============================] - 9s 947ms/step - loss: 6.8904e-04 - accuracy: 1.0000 - val_loss: 0.3460 - val_accuracy: 0.6667
# Epoch 25/50
# 9/9 [==============================] - 9s 948ms/step - loss: 6.5304e-04 - accuracy: 1.0000 - val_loss: 0.2762 - val_accuracy: 0.6667
# Epoch 26/50
# 9/9 [==============================] - 9s 912ms/step - loss: 4.8478e-04 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.6667
# Epoch 27/50
# 9/9 [==============================] - 9s 941ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 1.0000
# Epoch 28/50
# 9/9 [==============================] - 9s 931ms/step - loss: 4.0147e-04 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 1.0000
# Epoch 29/50
# 9/9 [==============================] - 9s 935ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 0.6667
# Epoch 30/50
# 9/9 [==============================] - 9s 951ms/step - loss: 5.3955e-04 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.6667
# Epoch 31/50
# 9/9 [==============================] - 9s 957ms/step - loss: 4.9495e-04 - accuracy: 1.0000 - val_loss: 0.6155 - val_accuracy: 0.6667
# Epoch 32/50
# 9/9 [==============================] - 9s 934ms/step - loss: 5.2328e-04 - accuracy: 1.0000 - val_loss: 0.6457 - val_accuracy: 0.6667
# Epoch 33/50
# 9/9 [==============================] - 9s 965ms/step - loss: 8.3914e-04 - accuracy: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.6667
# Epoch 34/50
# 9/9 [==============================] - 9s 969ms/step - loss: 0.0120 - accuracy: 0.9881 - val_loss: 0.5299 - val_accuracy: 0.6667
# Epoch 35/50
# 9/9 [==============================] - 9s 936ms/step - loss: 2.8456e-04 - accuracy: 1.0000 - val_loss: 1.1086 - val_accuracy: 0.6667
# Epoch 36/50
# 9/9 [==============================] - 9s 954ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.5734 - val_accuracy: 0.6667
# Epoch 37/50
# 9/9 [==============================] - 9s 930ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3291 - val_accuracy: 0.6667
# Epoch 38/50
# 9/9 [==============================] - 9s 934ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 1.0000
# Epoch 39/50
# 9/9 [==============================] - 9s 930ms/step - loss: 0.0174 - accuracy: 0.9881 - val_loss: 1.5678 - val_accuracy: 0.6667
# Epoch 40/50
# 9/9 [==============================] - 9s 945ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.2837 - val_accuracy: 0.6667
# Epoch 41/50
# 9/9 [==============================] - 9s 931ms/step - loss: 9.0495e-04 - accuracy: 1.0000 - val_loss: 0.9990 - val_accuracy: 0.6667
# Epoch 42/50
# 9/9 [==============================] - 9s 945ms/step - loss: 2.4506e-04 - accuracy: 1.0000 - val_loss: 0.8653 - val_accuracy: 0.6667
# Epoch 43/50
# 9/9 [==============================] - 9s 935ms/step - loss: 2.7377e-04 - accuracy: 1.0000 - val_loss: 0.7936 - val_accuracy: 0.6667
# Epoch 44/50
# 9/9 [==============================] - 9s 924ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.6667
# Epoch 45/50
# 9/9 [==============================] - 9s 936ms/step - loss: 9.2654e-04 - accuracy: 1.0000 - val_loss: 0.6682 - val_accuracy: 0.6667
# Epoch 46/50
# 9/9 [==============================] - 9s 956ms/step - loss: 3.8965e-04 - accuracy: 1.0000 - val_loss: 0.6771 - val_accuracy: 0.6667
# Epoch 47/50
# 9/9 [==============================] - 9s 936ms/step - loss: 1.6536e-04 - accuracy: 1.0000 - val_loss: 0.6676 - val_accuracy: 0.6667
# Epoch 48/50
# 9/9 [==============================] - 9s 938ms/step - loss: 4.8066e-04 - accuracy: 1.0000 - val_loss: 0.6625 - val_accuracy: 0.6667
# Epoch 49/50
# 9/9 [==============================] - 9s 982ms/step - loss: 2.2027e-04 - accuracy: 1.0000 - val_loss: 0.6568 - val_accuracy: 0.6667
# Epoch 50/50
# 9/9 [==============================] - 9s 917ms/step - loss: 9.5293e-05 - accuracy: 1.0000 - val_loss: 0.6512 - val_accuracy: 0.6667

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai số và độ chính xác
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  0.6511831283569336
# Độ chính xác  0.6666666865348816

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testanh/test/loi/loi (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Ho Viet Loi")
if(kq==1):
    print("Pham Huu Manh")
if(kq==2):
    print("Dang Tan Tai")
# Out:
# Ho Viet Loi

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testanh/test/tai/tai (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Ho Viet Loi")
if(kq==1):
    print("Pham Huu Manh")
if(kq==2):
    print("Dang Tan Tai")
# Out:
# Ho Viet Loi

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testanh/test/manh/manh (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Ho Viet Loi")
if(kq==1):
    print("Pham Huu Manh")
if(kq==2):
    print("Dang Tan Tai")
# Out:
# Pham Huu Manh
