# %%
#import library
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=20,
                                                 directory='../input/trainfruits/train',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=20,
                                                 directory='../input/testfruits/test',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 199 images belonging to 10 classes.
# Found 10 images belonging to 10 classes.

# %%
train_dataset.classes
train_dataset.class_indices
# Out:
# {'chomchom': 0,
#  'chuoi': 1,
#  'coc': 2,
#  'dudu': 3,
#  'man': 4,
#  'mit': 5,
#  'nhan': 6,
#  'nho': 7,
#  'oi': 8,
#  'xoai': 9}

# %%
import numpy as np  
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do chinh xac cao 
from keras import callbacks 
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-24 09:56:21.245510: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dense, Activation, Flatten
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=20,epochs=50,verbose=1,
                  validation_data=validation_dataset)
# Out:
# 2022-05-24 09:56:21.976031: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1
50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.7809 - val_accuracy: 0.8000
# Epoch 29/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0340 - accuracy: 0.9950 - val_loss: 1.1964 - val_accuracy: 0.7000
# Epoch 30/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 1.4040 - val_accuracy: 0.8000
# Epoch 31/50
# 10/10 [==============================] - 10s 1s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.2487 - val_accuracy: 0.8000
# Epoch 32/50
# 10/10 [==============================] - 10s 1s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.0384 - val_accuracy: 0.8000
# Epoch 33/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9455 - val_accuracy: 0.8000
# Epoch 34/50
# 10/10 [==============================] - 10s 1s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1127 - val_accuracy: 0.7000
# Epoch 35/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 1.5064 - val_accuracy: 0.8000
# Epoch 36/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3287 - val_accuracy: 0.7000
# Epoch 37/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.2234 - val_accuracy: 0.7000
# Epoch 38/50
# 10/10 [==============================] - 10s 1s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3170 - val_accuracy: 0.8000
# Epoch 39/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0054 - accuracy: 0.9950 - val_loss: 1.2458 - val_accuracy: 0.8000
# Epoch 40/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.0628 - val_accuracy: 0.7000
# Epoch 41/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1376 - val_accuracy: 0.9000
# Epoch 42/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.2497 - val_accuracy: 0.8000
# Epoch 43/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.4948 - val_accuracy: 0.8000
# Epoch 44/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5591 - val_accuracy: 0.8000
# Epoch 45/50
# 10/10 [==============================] - 10s 1s/step - loss: 0.0234 - accuracy: 0.9899 - val_loss: 1.6633 - val_accuracy: 0.8000
# Epoch 46/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.4276 - val_accuracy: 0.8000
# Epoch 47/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 2.0012 - val_accuracy: 0.8000
# Epoch 48/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.6844 - val_accuracy: 0.8000
# Epoch 49/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0089 - accuracy: 0.9950 - val_loss: 1.0226 - val_accuracy: 0.7000
# Epoch 50/50
# 10/10 [==============================] - 11s 1s/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 1.9606 - val_accuracy: 0.8000

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.9605998992919922
# Độ chính xác  0.800000011920929

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/chomchom/chomchom (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái chôm chôm

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/chuoi/chuoi (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái chuối

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/coc/coc (15).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# trái cốc

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/dudu/dudu (2).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái đu đủ

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/man/man (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái chôm chôm

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/man/man (15).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái mận

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/mit/mit (14).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái mít

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/nhan/nhan (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái nhãn

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/nho/nho (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái nho

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/oi/oi (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái ổi

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/testfruits/test/xoai/xoai (1).jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("Trái chôm chôm")
if(kq==1):
    print("Trái chuối ")
if(kq==2):
    print("trái cốc ")
if(kq==3):
    print("Trái đu đủ")    
if(kq==4):
    print("Trái mận")
if(kq==5):
    print("Trái mít")
if(kq==6):
    print("Trái nhãn")
if(kq==7):
    print("Trái nho")
if(kq==8):
    print("Trái ổi")
if(kq==9):
    print("Trái xoài")
# Out:
# Trái xoài
